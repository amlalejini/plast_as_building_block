# %% [markdown]
# # The Effects of Slip Mutations on the Evolution of Complexity

# %%
# imports
# %matplotlib inline
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# A few relevant settings/paths
exp_base_dir = "/Users/amlalejini/DataPlayground/slip_muts"
data_fpath = os.path.join(exp_base_dir, "processed", "SM_fdom_200k.data")

# %%
# Load data
df = pd.read_csv(data_fpath)
df
# Out:
#     treatment question        rep_id  fdom_env_count  fdom_phenotype_score  \
# 0        Q1T2       Q1  Q1T2__rep_42               1                     9
# 1        Q1T2       Q1  Q1T2__rep_35               1                     9
# 2        Q1T2       Q1  Q1T2__rep_48               1                     9
# 3        Q1T2       Q1   Q1T2__rep_6               1                     9
# 4        Q1T2       Q1  Q1T2__rep_26               1                     9
# 5        Q1T2       Q1  Q1T2__rep_14               1                     9
# 6        Q1T2       Q1  Q1T2__rep_19               1                     9
# 7        Q1T2       Q1  Q1T2__rep_13               1                     9
# 8        Q1T2       Q1   Q1T2__rep_1               1                     9
# 9        Q1T2       Q1  Q1T2__rep_21               1                     9
# 10       Q1T2       Q1  Q1T2__rep_32               1                     9
# ...

# %% [markdown]
# ## Normalized Phenotype Scores

# %%
# Visualize normalized phenotype scores
fig, ax = plt.subplots()
fig.set_size_inches(5, 5)
sns.violinplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q1"], order = ["Q1T0", "Q1T1", "Q1T2", "Q1T3"])
#sns.stripplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q1"], order = ["Q1T0", "Q1T1", "Q1T2", "Q1T3"])

fig, ax = plt.subplots()
fig.set_size_inches(5, 5)
sns.violinplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q2"], order = ["Q2T0", "Q2T1", "Q2T2", "Q2T3"])
# sns.swarmplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q2"], order = ["Q2T0", "Q2T1", "Q2T2", "Q2T3"])

fig, ax = plt.subplots()
fig.set_size_inches(5, 5)
sns.violinplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q3"], order = ["Q3T0", "Q3T1", "Q3T2", "Q3T3"])
# sns.swarmplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q3"], order = ["Q3T0", "Q3T1", "Q3T2", "Q3T3"])

# %% [markdown]
# ## Phenotype Scores

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
sns.violinplot(x = "treatment", y = "fdom_phenotype_score", data = df[df["question"] == "Q1"], order = ["Q1T0", "Q1T1", "Q1T2", "Q1T3"])
sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df[df["question"] == "Q1"], order = ["Q1T0", "Q1T1", "Q1T2", "Q1T3"])

fig, ax = plt.subplots()
fig.set_size_inches(5, 5)
sns.violinplot(x = "treatment", y = "fdom_phenotype_score", data = df[df["question"] == "Q2"], order = ["Q2T0", "Q2T1", "Q2T2", "Q2T3"])
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df[df["question"] == "Q2"], order = ["Q2T0", "Q2T1", "Q2T2", "Q2T3"])

fig, ax = plt.subplots()
fig.set_size_inches(5, 5)
sns.violinplot(x = "treatment", y = "fdom_phenotype_score", data = df[df["question"] == "Q3"], order = ["Q3T0", "Q3T1", "Q3T2", "Q3T3"])
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df[df["question"] == "Q3"], order = ["Q3T0", "Q3T1", "Q3T2", "Q3T3"])

# %% [markdown]
# ## Final Dominant Lineage Scores Over Time

# %%
ts_fpath = os.path.join(exp_base_dir, "processed", "SM_lineage_score_ts.csv")

# %%
# # Load data
ts_df = pd.read_csv(ts_fpath)
q1ts_df = ts_df[ts_df["question"] == "Q1"]
q2ts_df = ts_df[ts_df["question"] == "Q2"]
q3ts_df = ts_df[ts_df["question"] == "Q3"]

# %%
# # Plot score over time
fig, ax = plt.subplots()
fig.set_size_inches(30, 15)
sns.tsplot(data=q1ts_df, time="update", unit="rep",
           condition="treatment", value="score")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(30, 15)
sns.tsplot(data=q2ts_df, time="update", unit="rep",
           condition="treatment", value="score")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(30, 15)
sns.tsplot(data=q3ts_df, time="update", unit="rep",
           condition="treatment", value="score")

# %%
# cp = ['#1b9e77','#d95f02','#7570b3']
# pal = sns.color_palette(cp)

# fig, ax = plt.subplots()
# fig.set_size_inches(30, 15)
# sns.tsplot(data=q2ts_df, time="update", unit="rep",
#            condition="treatment", value="score", color = {"Q2T1": pal[0], "Q2T2": pal[1], "Q2T3": pal[2]})

# %%
# cp = ['#1b9e77','#d95f02','#7570b3']
# pal = sns.color_palette(cp)
# sns.palplot(pal)
