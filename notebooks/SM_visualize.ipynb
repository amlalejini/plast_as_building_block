# %% [markdown]
# # The Effects of Slip Mutations on the Evolution of Complexity

# %%
# imports
# %matplotlib inline
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# A few relevant settings/paths
exp_base_dir = "/Users/amlalejini/DataPlayground/slip_muts/iter_2"
data_fpath = os.path.join(exp_base_dir, "processed", "slipmuts_q1q2_iter2_fdom_200k2.csv")

# %%
# Load data
df = pd.read_csv(data_fpath)
df
# Out:
#                          treatment question  \
# 0           Q2__Slip_DUP__MinGen_0       Q2
# 1           Q2__Slip_DUP__MinGen_0       Q2
# 2           Q2__Slip_DUP__MinGen_0       Q2
# 3           Q2__Slip_DUP__MinGen_0       Q2
# 4           Q2__Slip_DUP__MinGen_0       Q2
# 5           Q2__Slip_DUP__MinGen_0       Q2
# 6           Q2__Slip_DUP__MinGen_0       Q2
# 7           Q2__Slip_DUP__MinGen_0       Q2
# 8           Q2__Slip_DUP__MinGen_0       Q2
# 9           Q2__Slip_DUP__MinGen_0       Q2
# 10          Q2__Slip_DUP__MinGen_0       Q2
# 11          Q2__Slip_DUP__MinGen_0       Q2
# 12          Q2__Slip_DUP__MinGen_0       Q2
# 13          Q2__Slip_DUP__MinGen_0       Q2
# 14          Q2__Slip_DUP__MinGen_0       Q2
# 15          Q2__Slip_DUP__MinGen_0       Q2
# 16          Q2__Slip_DUP__MinGen_0       Q2
# 17          Q2__Slip_DUP__MinGen_0       Q2
# 18          Q2__Slip_DUP__MinGen_0       Q2
# 19          Q2__Slip_DUP__MinGen_0       Q2
# ...

# %%
df_mg100 = df[df["treatment"].str.contains("MinGen_100") == True]
df_mg0 = df[df["treatment"].str.contains("MinGen_0") == True]

# %%
label_map = {"Slip_NONE": "Baseline", "HIGHMUT": "High Mutation Rate", "Slip_SCATTER": "Slip: Scatter", "Slip_NOP": "Slip: nop-X", "Slip_RAND": "Slip: Random", "Slip_SCRAM": "Slip: Scrambled", "Slip_DUP": "Slip: Duplicate"}

q1_mg100_order = ["Q1__Slip_NONE__MinGen_100", "Q1__HIGHMUT__MinGen_100","Q1__Slip_SCATTER__MinGen_100",
                   "Q1__Slip_NOP__MinGen_100", "Q1__Slip_RAND__MinGen_100", "Q1__Slip_SCRAM__MinGen_100",
                   "Q1__Slip_DUP__MinGen_100"]

q2_mg100_order = ["Q2__Slip_NONE__MinGen_100", "Q2__HIGHMUT__MinGen_100","Q2__Slip_SCATTER__MinGen_100",
                   "Q2__Slip_NOP__MinGen_100", "Q2__Slip_RAND__MinGen_100", "Q2__Slip_SCRAM__MinGen_100",
                   "Q2__Slip_DUP__MinGen_100"]


q1_mg0_order = ["Q1__Slip_NONE__MinGen_0", "Q1__HIGHMUT__MinGen_0","Q1__Slip_SCATTER__MinGen_0",
                   "Q1__Slip_NOP__MinGen_0", "Q1__Slip_RAND__MinGen_0", "Q1__Slip_SCRAM__MinGen_0",
                   "Q1__Slip_DUP__MinGen_0"]

q2_mg0_order = ["Q2__Slip_NONE__MinGen_0", "Q2__HIGHMUT__MinGen_0","Q2__Slip_SCATTER__MinGen_0",
                   "Q2__Slip_NOP__MinGen_0", "Q2__Slip_RAND__MinGen_0", "Q2__Slip_SCRAM__MinGen_0",
                   "Q2__Slip_DUP__MinGen_0"]

q1_mg100_labels = [label_map[t.split("__")[1]] for t in q1_mg100_order]
q2_mg100_labels = [label_map[t.split("__")[1]] for t in q2_mg100_order]
q1_mg0_labels = [label_map[t.split("__")[1]] for t in q1_mg0_order]
q2_mg0_labels = [label_map[t.split("__")[1]] for t in q2_mg0_order]

# %% [markdown]
# ## Normalized Phenotype Scores

# %%
# Visualize normalized phenotype scores
# fig, ax = plt.subplots()
# fig.set_size_inches(5, 5)
#sns.violinplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df_mg100[df_mg100["question"] == "Q1"])
#sns.stripplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q1"], order = ["Q1T0", "Q1T1", "Q1T2", "Q1T3"])

# fig, ax = plt.subplots()
# fig.set_size_inches(5, 5)
# sns.violinplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q2"], order = ["Q2T0", "Q2T1", "Q2T2", "Q2T3"])
# # sns.swarmplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q2"], order = ["Q2T0", "Q2T1", "Q2T2", "Q2T3"])

# fig, ax = plt.subplots()
# fig.set_size_inches(5, 5)
# sns.violinplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q3"], order = ["Q3T0", "Q3T1", "Q3T2", "Q3T3"])
# # sns.swarmplot(x = "treatment", y = "fdom_norm_phenotype_score", data = df[df["question"] == "Q3"], order = ["Q3T0", "Q3T1", "Q3T2", "Q3T3"])

# %% [markdown]
# ## Phenotype Scores

# %% [markdown]
# ### Question 1 (Static Logic 9): Final Dominant, Min Genome Size 100

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg100[df_mg100["question"] == "Q1"], order = q1_mg100_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg100[df_mg100["question"] == "Q1"], order = q1_mg100_order)
ax.set_xticklabels(q1_mg100_labels)
ax.set_ylabel("Final Dominant Trait Count")
ax.set_xlabel("Condition")
ax.set_title("Static logic 9 -- Min Genome Size: 100")
ax.set_ylim(0, 10)
ax.set_yticks([x for x in range(0, 10)])

# %% [markdown]
# #### Final Dominant, Gestation time

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.violinplot(x = "treatment", y = "fdom_gestation_time", data = df_mg100[df_mg100["question"] == "Q1"], order = q1_mg100_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg100[df_mg100["question"] == "Q1"], order = q1_mg100_order)
ax.set_xticklabels(q1_mg100_labels)
ax.set_ylabel("Final Gestation Time (updates)")
ax.set_xlabel("Condition")
ax.set_title("Static logic 9 -- Min Genome Size: 100")

# %% [markdown]
# #### Final dominant, genome length

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_genome_length", data = df_mg100[df_mg100["question"] == "Q1"], order = q1_mg100_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg100[df_mg100["question"] == "Q1"], order = q1_mg100_order)
ax.set_xticklabels(q1_mg100_labels)
ax.set_ylabel("Final Genome Length")
ax.set_xlabel("Condition")
ax.set_title("Static logic 9 -- Min Genome Size: 100")
ax.set_ylim(0, 1000)
# Out:
# (0, 1000)

# %% [markdown]
# ### Question 1 (Static Logic 9): Final Dominant, Min Genome Size: None

# %%
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.violinplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg0[df_mg0["question"] == "Q1"], order = q1_mg0_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg0[df_mg0["question"] == "Q1"], order = q1_mg0_order)
ax.set_xticklabels(q1_mg0_labels)
ax.set_ylabel("Final Dominant Trait Count")
ax.set_xlabel("Condition")
ax.set_title("Static logic 9 -- Min Genome Size: 0")
ax.set_ylim(0, 10)
ax.set_yticks([x for x in range(0, 10)])

# %% [markdown]
# #### Final Dominant, Gestation Time

# %%
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.violinplot(x = "treatment", y = "fdom_gestation_time", data = df_mg0[df_mg0["question"] == "Q1"], order = q1_mg0_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg0[df_mg0["question"] == "Q1"], order = q1_mg0_order)
ax.set_xticklabels(q1_mg0_labels)
ax.set_ylabel("Final Dominant Gestation Time")
ax.set_xlabel("Condition")
ax.set_title("Static logic 9 -- Min Genome Size: 0")

# %% [markdown]
# #### Final dominant, genome length

# %%
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_genome_length", data = df_mg0[df_mg0["question"] == "Q1"], order = q1_mg0_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg0[df_mg0["question"] == "Q1"], order = q1_mg0_order)
ax.set_xticklabels(q1_mg0_labels)
ax.set_ylabel("Final Dominant Genome Length")
ax.set_xlabel("Condition")
ax.set_title("Static logic 9 -- Min Genome Size: 0")
ax.set_ylim(0, 1000)
# Out:
# (0, 1000)

# %% [markdown]
# ### Question 2: 16 environments (NAND, NOT, ORN, AND) randomly changing. Sensors available. Min Genome size: 100

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg100[df_mg100["question"] == "Q2"], order = q2_mg100_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg100[df_mg100["question"] == "Q2"], order = q2_mg100_order)
ax.set_xticklabels(q2_mg100_labels)
ax.set_ylabel("Final Dominant Trait Count")
ax.set_xlabel("Condition")
ax.set_title("16 Environments, Randomly Changing (NAND, NOT, ORN, AND) -- Min Genome Size: 100")
ax.set_ylim(-64, 64)
# Out:
# (-64, 64)

# %% [markdown]
# #### Final dominant, gestation time

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_gestation_time", data = df_mg100[df_mg100["question"] == "Q2"], order = q2_mg100_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg100[df_mg100["question"] == "Q2"], order = q2_mg100_order)
ax.set_xticklabels(q2_mg100_labels)
ax.set_ylabel("Gestation time (updates)")
ax.set_xlabel("Condition")
ax.set_title("Gestation Time")
#ax.set_ylim(-64, 64)

# %% [markdown]
# #### Final dominant, genome length

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_genome_length", data = df_mg100[df_mg100["question"] == "Q2"], order = q2_mg100_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg100[df_mg100["question"] == "Q2"], order = q2_mg100_order)
ax.set_xticklabels(q2_mg100_labels)
ax.set_ylabel("Genome length")
ax.set_xlabel("Condition")
ax.set_title("Genome Length")

# %% [markdown]
# ### Question 2: 16 environments (NAND, NOT, ORN, AND) randomly changing. Sensors available. Min Genome size: 0

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg0[df_mg0["question"] == "Q2"], order = q2_mg0_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg0[df_mg0["question"] == "Q2"], order = q2_mg0_order)
ax.set_xticklabels(q2_mg0_labels)
ax.set_ylabel("Final Dominant Trait Count")
ax.set_xlabel("Condition")
ax.set_title("16 Environments, Randomly Changing (NAND, NOT, ORN, AND) -- Min Genome Size: 0")
ax.set_ylim(-64, 64)
# Out:
# (-64, 64)

# %% [markdown]
# #### Final dominant, gestation time

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_gestation_time", data = df_mg0[df_mg0["question"] == "Q2"], order = q2_mg0_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg0[df_mg0["question"] == "Q2"], order = q2_mg0_order)
ax.set_xticklabels(q2_mg0_labels)
ax.set_ylabel("Final Dominant Gestation Time (updates)")
ax.set_xlabel("Condition")
ax.set_title("Gestation Time")

# %% [markdown]
# #### Final dominant, genome length

# %%
# Visualize non-normalized scores
fig, ax = plt.subplots()
fig.set_size_inches(50, 20)
sns.boxplot(x = "treatment", y = "fdom_genome_length", data = df_mg0[df_mg0["question"] == "Q2"], order = q2_mg0_order)
# sns.swarmplot(x = "treatment", y = "fdom_phenotype_score", data = df_mg0[df_mg0["question"] == "Q2"], order = q2_mg0_order)
ax.set_xticklabels(q2_mg0_labels)
ax.set_ylabel("Final Dominant Genome Length")
ax.set_xlabel("Condition")
ax.set_title("Genome Length")

# %% [markdown]
# ## Final Dominant Lineage Scores Over Time

# %%
q1q2ts_fpath = os.path.join(exp_base_dir, "processed", "SM_q1q2_lineage_score_ts.csv")

# %%
# # Load data
ts_df = pd.read_csv(q1q2ts_fpath)
q1ts_df = ts_df[ts_df["question"] == "Q1"]
q2ts_df = ts_df[ts_df["question"] == "Q2"]

q1mg100ts_df = q1ts_df[q1ts_df["treatment"].str.contains("MinGen_100") == True]
q2mg100ts_df = q2ts_df[q2ts_df["treatment"].str.contains("MinGen_100") == True]
q1mg0ts_df = q1ts_df[q1ts_df["treatment"].str.contains("MinGen_0") == True]
q2mg0ts_df = q2ts_df[q2ts_df["treatment"].str.contains("MinGen_0") == True]

# %%
colors = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f']
q1_mg100_cmap = {q1_mg100_order[con]:colors[con] for con in range(0, len(q1_mg100_order))}
q2_mg100_cmap = {q2_mg100_order[con]:colors[con] for con in range(0, len(q2_mg100_order))} 
q1_mg0_cmap = {q1_mg0_order[con]:colors[con] for con in range(0, len(q1_mg0_order))} 
q2_mg0_cmap = {q2_mg0_order[con]:colors[con] for con in range(0, len(q2_mg0_order))}

# %% [markdown]
# ### Static Logic 9 Min Genome 100

# %%
# # Plot score over time
fig, ax = plt.subplots()
fig.set_size_inches(30, 15)
sns.tsplot(data=q1mg100ts_df, time="update", unit="rep",
           condition="treatment", value="score", color=q1_mg100_cmap)

# %% [markdown]
# ### Static Logic 9 Min Genome 0

# %%
# # Plot score over time
fig, ax = plt.subplots()
fig.set_size_inches(30, 15)
sns.tsplot(data=q1mg0ts_df, time="update", unit="rep",
           condition="treatment", value="score", color=q1_mg0_cmap)

# %% [markdown]
# ### 16 env (NAND, NOT, ORN, AND) randomly changing, Min Genome 100

# %%
# # Plot score over time
fig, ax = plt.subplots()
fig.set_size_inches(30, 15)
sns.tsplot(data=q2mg100ts_df, time="update", unit="rep",
           condition="treatment", value="score", color=q2_mg100_cmap)
ax.set_ylim(-10, 64)
# Out:
# (-10, 64)

# %% [markdown]
# ### 16 env (NAND, NOT, ORN, AND) randomly changing, Min Genome 0

# %%
# # Plot score over time
fig, ax = plt.subplots()
fig.set_size_inches(30, 15)
sns.tsplot(data=q2mg0ts_df, time="update", unit="rep",
           condition="treatment", value="score", color=q2_mg0_cmap)
ax.set_ylim(-10, 64)
# Out:
# (-10, 64)

# %%
# cp = ['#1b9e77','#d95f02','#7570b3']
# pal = sns.color_palette(cp)

# fig, ax = plt.subplots()
# fig.set_size_inches(30, 15)
# sns.tsplot(data=q2ts_df, time="update", unit="rep",
#            condition="treatment", value="score", color = {"Q2T1": pal[0], "Q2T2": pal[1], "Q2T3": pal[2]})

# %%
# cp = ['#1b9e77','#d95f02','#7570b3']
# pal = sns.color_palette(cp)
# sns.palplot(pal)
